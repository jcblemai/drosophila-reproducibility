# %%
import pandas as pd
import pickle
import preprocess_utils
import numpy as np
import json, plot_info

from_database = False

if from_database:
    # Load tables from database 
    dfs = preprocess_utils.load_all_tables()
else:
    # Open the file in binary read mode and load the pickle data
    with open('preprocessed_data/dfs.pickle', 'rb') as f:
        dfs = pickle.load(f)
        for key, df in dfs.items():
            print(f"DataFrame {key:<20} has {len(df):<6} rows and {len(df.columns):<6} columns.")

if from_database:
    # Save tables to pickle
    with open('preprocessed_data/dfs.pickle', 'wb') as f:
        pickle.dump(dfs, f)

    # load it back with:
    with open('preprocessed_data/dfs.pickle', 'rb') as f:
        dfs = pickle.load(f)
# Out:
# DataFrame abuse_report_types   has 4      rows and 4      columns.
# DataFrame abuse_reports        has 0      rows and 8      columns.
# DataFrame ar_internal_metadata has 1      rows and 4      columns.
# DataFrame articles             has 400    rows and 33     columns.
# DataFrame assertion_types      has 10     rows and 11     columns.
# DataFrame assertion_versions   has 19668  rows and 10     columns.
# DataFrame assertions           has 13941  rows and 14     columns.
# DataFrame assertions_genes     has 2053   rows and 2      columns.
# DataFrame assertions_tags      has 403    rows and 2      columns.
# DataFrame assertions_technique_types has 0      rows and 2      columns.
# DataFrame assertions_techniques has 0      rows and 2      columns.
# DataFrame assessment_types     has 13     rows and 9      columns.
# DataFrame assessments          has 0      rows and 6      columns.
# DataFrame authors              has 797    rows and 10     columns.
# DataFrame banned_orcid_users   has 0      rows and 5      columns.
# DataFrame career_stages        has 6      rows and 2      columns.
# DataFrame claim_types          has 0      rows and 4      columns.
# DataFrame claims               has 0      rows and 6      columns.
# DataFrame comment_checks       has 0      rows and 5      columns.
# DataFrame comments             has 0      rows and 6      columns.
# DataFrame db_sets              has 10     rows and 4      columns.
# DataFrame ensembl_subdomains   has 6      rows and 4      columns.
# DataFrame expertise_levels     has 2      rows and 2      columns.
# DataFrame gene_names           has 29555831 rows and 4      columns.
# DataFrame gene_set_items       has 3277264 rows and 7      columns.
# DataFrame gene_sets            has 1271   rows and 12     columns.
# DataFrame genes                has 13914654 rows and 16     columns.
# DataFrame journals             has 456    rows and 6      columns.
# DataFrame orcid_users          has 69     rows and 5      columns.
# DataFrame organisms            has 446    rows and 12     columns.
# DataFrame reason_types         has 12     rows and 4      columns.
# DataFrame reasons              has 191    rows and 8      columns.
# DataFrame rel_types            has 3      rows and 7      columns.
# DataFrame rels                 has 10832  rows and 11     columns.
# DataFrame schema_migrations    has 6      rows and 1      columns.
# DataFrame sessions             has 1518801 rows and 5      columns.
# DataFrame shares               has 77     rows and 14     columns.
# DataFrame statuses             has 6      rows and 6      columns.
# DataFrame tags                 has 145    rows and 5      columns.
# DataFrame technique_types      has 0      rows and 5      columns.
# DataFrame techniques           has 18     rows and 5      columns.
# DataFrame tool_types           has 4      rows and 2      columns.
# DataFrame tools                has 29     rows and 9      columns.
# DataFrame users                has 99     rows and 15     columns.
# DataFrame workspace_orcid_users has 1      rows and 6      columns.
# DataFrame workspaces           has 1      rows and 17     columns.

# %% [markdown]
# ## A. Database articles, claims and authors

# %% [markdown]
# ### A.1. Process journal articles from the database

# %%
# Process articles
articles = preprocess_utils.clean_df_from_database(dfs["articles"])
articles = articles.rename(columns={"id": "article_id"})
# add journals to articles:
journals = preprocess_utils.clean_df_from_database(dfs["journals"])
journals = journals.drop('tag', axis=1).rename(columns={"id": "journal_id", "name": "journal_name"})
articles = articles.merge(journals, on="journal_id", how="left", suffixes=('', '_journal')).drop("journal_id", axis=1)


# Extract first and last authors from authors_txt
def extract_authors(authors_txt):
    if isinstance(authors_txt, str) and authors_txt:
        authors_list = authors_txt.split(';')
        first_author = authors_list[0].strip() if authors_list else None
        last_author = authors_list[-1].strip() if authors_list else None
        return pd.Series([first_author, last_author])
    return pd.Series([None, None])

# Apply the function to create new columns
articles[['first_author_extracted', 'last_author_extracted']] = articles['authors_txt'].apply(extract_authors)

# Check the results
print(f"Total articles: {len(articles)}")
print(f"Articles with first author: {articles['first_author_extracted'].notna().sum()}")
print(f"Articles with last author: {articles['last_author_extracted'].notna().sum()}")

articles = articles.drop(columns=["key", "references_txt", "additional_context", "num",  "nber_panels", "large_scale", "nber_tables", "published_at"])


# Display the first few rows to verify
articles[['authors_txt', 'first_author_extracted', 'last_author_extracted']].head()
# Out:
# Total articles: 400
# Articles with first author: 400
# Articles with last author: 400
#                                          authors_txt first_author_extracted  \
# 0                                  Rizki RM;Rizki TM               Rizki RM
# 1             Leulier F;Lhocine N;Lemaitre B;Meier P              Leulier F
# 2  Kim YS;Han SJ;Ryu JH;Choi KH;Hong YS;Chung YH;...                 Kim YS
# 3                      Tingvall TO;Roos E;Engström Y            Tingvall TO
# 4                   Bhaskar V;Valentine SA;Courey AJ              Bhaskar V
#
#   last_author_extracted
# 0              Rizki TM
# 1               Meier P
# 2                Lee WJ
# 3            Engström Y
# 4             Courey AJ

# %%
# We need to analyze and clean up affiliations in the articles dataframe

def extract_primary_affiliation(affs_json_str):
    """Extract the first affiliation from the JSON string, safely handle bad JSON format."""
    try:
        # Parse the JSON string to a Python object
        affs_list = json.loads(affs_json_str)
        
        # Get the first non-empty affiliation
        for aff in affs_list:
            if aff and isinstance(aff, list) and len(aff) > 0 and aff[0].strip():
                return aff[0].strip()
        
        return None  # No valid affiliation found
    except (json.JSONDecodeError, TypeError, IndexError):
        # Handle poorly formatted JSON or other errors
        return None

# Create a new column with clean affiliations
articles['primary_affiliation'] = articles['affs_json'].apply(extract_primary_affiliation)

# Count articles with multiple vs. single affiliations
def count_affiliations(affs_json_str):
    """Count the number of non-empty affiliations in the JSON string."""
    try:
        affs_list = json.loads(affs_json_str)
        count = sum(1 for aff in affs_list if aff and isinstance(aff, list) and len(aff) > 0 and aff[0].strip())
        return count
    except (json.JSONDecodeError, TypeError, IndexError):
        return 0

articles['affiliation_count'] = articles['affs_json'].apply(count_affiliations)

# Identify articles with multiple affiliations
multiple_aff_articles = articles[articles['affiliation_count'] > 1]

# Print summary statistics
print(f"Total articles: {len(articles)}")
print(f"Articles with 1 affiliation: {len(articles[articles['affiliation_count'] == 1])}")
print(f"Articles with multiple affiliations: {len(multiple_aff_articles)}")
print(f"Articles with no valid affiliations: {len(articles[articles['affiliation_count'] == 0])}")

# Sample of articles with multiple affiliations
if not multiple_aff_articles.empty:
    print("\nSample of articles with multiple affiliations:")
    sample = multiple_aff_articles.head(5)
    for _, row in sample.iterrows():
        print(f"Article ID: {row['article_id']}, Title: {row['title'][:50]}...")
        try:
            affs = json.loads(row['affs_json'])
            for i, aff in enumerate(affs):
                if aff and isinstance(aff, list) and len(aff) > 0 and aff[0].strip():
                    print(f"  Affiliation {i+1}: {aff[0]}")
        except:
            print("  Error parsing affiliations")
        print()
# Out:
# Total articles: 400
# Articles with 1 affiliation: 387
# Articles with multiple affiliations: 0
# Articles with no valid affiliations: 13

# %%
articles = articles.drop(columns=["affs_json", "affiliation_count"])

# Update impact factor for "Proceedings. Biological sciences" and standardize the journal name
articles.loc[articles["journal_name"] == "Proceedings. Biological sciences", "impact_factor"] = 4.7 
articles.loc[articles["journal_name"] == "Proceedings. Biological sciences", "journal_name"] = "Proceedings Biological Sciences"

# %%
articles["country"] =  articles["primary_affiliation"].apply(lambda x: x.split(",")[-1].strip().strip('.') if isinstance(x, str) else None)

# %%
articles
# Out:
#      article_id                                        authors_txt  \
# 0          3347                                  Rizki RM;Rizki TM
# 1          1987             Leulier F;Lhocine N;Lemaitre B;Meier P
# 2          2761  Kim YS;Han SJ;Ryu JH;Choi KH;Hong YS;Chung YH;...
# 3          2649                      Tingvall TO;Roos E;Engström Y
# 4          3441                   Bhaskar V;Valentine SA;Courey AJ
# ..          ...                                                ...
# 395        1882        Derré I;Pypaert M;Dautry-Varsat A;Agaisse H
# 396        1815    Schmidt RL;Trejo TR;Plummer TB;Platt JL;Tang AH
# 397        1884     Avet-Rochex A;Perrin J;Bergeret E;Fauvarque MO
# 398        2041                Tanji T;Ohashi-Kobayashi A;Natori S
# 399        1926  Kurucz E;Márkus R;Zsámboki J;Folkl-Medzihradsz...
#
#                                                  title      pmid volume issue  \
# 0    Cell interactions in the differentiation of a ...    111992     12     3
# 1    The Drosophila inhibitor of apoptosis protein ...  16894030     26    21
# 2    Lipopolysaccharide-activated kinase, an essent...  10636911    275     3
# 3    The GATA factor Serpent is required for the on...  11274409     98     7
# 4    A functional interaction between dorsal and co...  10660560    275     6
# ..                                                 ...       ...    ...   ...
# 395  RNAi screen in Drosophila cells reveals the in...  17967059      3    10
# 396  Infection-induced proteolysis of PGRP-LC contr...  18308747     22     3
# 397  Rac2 is a major actor of Drosophila resistance...  17903178     12    10
# 398  Participation of a galactose-specific C-type l...  16475980    396     1
# 399  Nimrod, a putative phagocytosis receptor with ...  17363253     17     7
#
#                                               abstract  year  \
# 0    The cellular events in the formation of melano...  1979
# 1    The founding member of the inhibitor of apopto...  2006
# 2    Eukaryotic organisms use a similar Rel/NF-kapp...  2000
# 3    Innate immunity in Drosophila is characterized...  2001
# 4    To identify proteins that regulate the functio...  2000
# ..                                                 ...   ...
# 395  Chlamydia spp. are intracellular obligate bact...  2007
# 396  The Drosophila immune deficiency (IMD) pathway...  2008
# 397  Pathogen recognition and engulfment by phagocy...  2007
# 398  A galactose-specific C-type lectin has been pu...  2006
# 399  The hemocytes, the blood cells of Drosophila, ...  2007
#
#                                           journal_name  impact_factor  \
# 0    Differentiation; research in biological diversity           3.39
# 1                       Molecular and cellular biology           5.30
# 2                  The Journal of biological chemistry           4.80
# 3    Proceedings of the National Academy of Science...          11.10
# 4                  The Journal of biological chemistry           4.80
# ..                                                 ...            ...
# 395                                     PLoS pathogens           6.70
# 396  FASEB journal : official publication of the Fe...           4.80
# 397  Genes to cells : devoted to molecular &amp; ce...           2.10
# 398                            The Biochemical journal           4.10
# 399                               Current biology : CB           9.20
#
#     first_author_extracted last_author_extracted  \
# 0                 Rizki RM              Rizki TM
# 1                Leulier F               Meier P
# 2                   Kim YS                Lee WJ
# 3              Tingvall TO            Engström Y
# 4                Bhaskar V             Courey AJ
# ..                     ...                   ...
# 395                Derré I             Agaisse H
# 396             Schmidt RL               Tang AH
# 397          Avet-Rochex A          Fauvarque MO
# 398                Tanji T              Natori S
# 399               Kurucz E                Andó I
#
#                                    primary_affiliation  \
# 0                                                 None
# 1    The Breakthrough Toby Robins Breast Cancer Res...
# 2    Laboratory of Immunology, Medical Research Cen...
# 3    Department of Molecular Biology and Functional...
# 4    Department of Chemistry and Biochemistry, Univ...
# ..                                                 ...
# 395  Section of Microbial Pathogenesis, Yale Univer...
# 396  Department of Biochemistry and Molecular Biolo...
# 397  Commissariat à l'Energie Atomique, DSV, iRTSV,...
# 398  Department of Cell Biochemistry, Graduate Scho...
# 399  Institute of Genetics, Biological Research Cen...
#
#                             country
# 0                              None
# 1    UK. francois.leulier@icr.ac.uk
# 2                       South Korea
# 3                            Sweden
# 4                               USA
# ..                              ...
# 395    USA. isabelle.derre@yale.edu
# 396                    MN 55905 USA
# 397                          France
# 398                           Japan
# 399                         Hungary
#
# [400 rows x 14 columns]

# %%
country_list = ["Germany", "France", "Italy", "Switzerland", "Belgum", "Sweden", "Finland", 
                    "Hungary", "Israel", "Canada", "UK", "USA", "Belgium", "China"]
for i, row in articles.iterrows():
    if isinstance(row["country"], str):
        if "United States" in row["country"]:
            articles.at[i, "country"] = "USA"
        elif "United Kingdom" in row["country"]:
            articles.at[i, "country"] = "UK"
        elif "La Jolla" in row["country"] or "Beckman Center" in row["country"]:
            articles.at[i, "country"] = "USA"
        elif "Pusan" in row["primary_affiliation"]:
            articles.at[i, "country"] = "South Korea"
        for country in country_list:
            if country in row["country"]:
                articles.at[i, "country"] = country
for a, r in articles["country"].value_counts().items():
    print(a,r)
# Out:
# USA 133
# France 88
# Sweden 56
# UK 19
# South Korea 13
# Japan 12
# China 12
# Germany 8
# Canada 7
# Belgium 6
# Korea 6
# Finland 6
# Switzerland 6
# Hungary 5
# Italy 2
# Israel 2
# Spain 2
# Russia 1
# Portugal 1
# Czech Republic 1
# Greece 1

# %%
print(articles[articles["country"]=="609-735"]["primary_affiliation"].values)
# Out:
# []

# %%
for _, row in articles[["primary_affiliation", "country"]].iterrows():
    if pd.isna(row["country"]):
        print(row["primary_affiliation"], row["country"])
# Out:
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None
# None None

# %%
row["country"]
# Out:
# 'Hungary'

# %%
articles = articles.apply(preprocess_utils.safe_strip)
articles.to_csv("preprocessed_data/articles_db.csv", index=False)

# %%
articles
# Out:
#      article_id                                        authors_txt  \
# 0          3347                                  Rizki RM;Rizki TM
# 1          1987             Leulier F;Lhocine N;Lemaitre B;Meier P
# 2          2761  Kim YS;Han SJ;Ryu JH;Choi KH;Hong YS;Chung YH;...
# 3          2649                      Tingvall TO;Roos E;Engström Y
# 4          3441                   Bhaskar V;Valentine SA;Courey AJ
# ..          ...                                                ...
# 395        1882        Derré I;Pypaert M;Dautry-Varsat A;Agaisse H
# 396        1815    Schmidt RL;Trejo TR;Plummer TB;Platt JL;Tang AH
# 397        1884     Avet-Rochex A;Perrin J;Bergeret E;Fauvarque MO
# 398        2041                Tanji T;Ohashi-Kobayashi A;Natori S
# 399        1926  Kurucz E;Márkus R;Zsámboki J;Folkl-Medzihradsz...
#
#                                                  title      pmid volume issue  \
# 0    Cell interactions in the differentiation of a ...    111992     12     3
# 1    The Drosophila inhibitor of apoptosis protein ...  16894030     26    21
# 2    Lipopolysaccharide-activated kinase, an essent...  10636911    275     3
# 3    The GATA factor Serpent is required for the on...  11274409     98     7
# 4    A functional interaction between dorsal and co...  10660560    275     6
# ..                                                 ...       ...    ...   ...
# 395  RNAi screen in Drosophila cells reveals the in...  17967059      3    10
# 396  Infection-induced proteolysis of PGRP-LC contr...  18308747     22     3
# 397  Rac2 is a major actor of Drosophila resistance...  17903178     12    10
# 398  Participation of a galactose-specific C-type l...  16475980    396     1
# 399  Nimrod, a putative phagocytosis receptor with ...  17363253     17     7
#
#                                               abstract  year  \
# 0    The cellular events in the formation of melano...  1979
# 1    The founding member of the inhibitor of apopto...  2006
# 2    Eukaryotic organisms use a similar Rel/NF-kapp...  2000
# 3    Innate immunity in Drosophila is characterized...  2001
# 4    To identify proteins that regulate the functio...  2000
# ..                                                 ...   ...
# 395  Chlamydia spp. are intracellular obligate bact...  2007
# 396  The Drosophila immune deficiency (IMD) pathway...  2008
# 397  Pathogen recognition and engulfment by phagocy...  2007
# 398  A galactose-specific C-type lectin has been pu...  2006
# 399  The hemocytes, the blood cells of Drosophila, ...  2007
#
#                                           journal_name  impact_factor  \
# 0    Differentiation; research in biological diversity           3.39
# 1                       Molecular and cellular biology           5.30
# 2                  The Journal of biological chemistry           4.80
# 3    Proceedings of the National Academy of Science...          11.10
# 4                  The Journal of biological chemistry           4.80
# ..                                                 ...            ...
# 395                                     PLoS pathogens           6.70
# 396  FASEB journal : official publication of the Fe...           4.80
# 397  Genes to cells : devoted to molecular & cellul...           2.10
# 398                            The Biochemical journal           4.10
# 399                               Current biology : CB           9.20
#
#     first_author_extracted last_author_extracted  \
# 0                 Rizki RM              Rizki TM
# 1                Leulier F               Meier P
# 2                   Kim YS                Lee WJ
# 3              Tingvall TO            Engström Y
# 4                Bhaskar V             Courey AJ
# ..                     ...                   ...
# 395                Derré I             Agaisse H
# 396             Schmidt RL               Tang AH
# 397          Avet-Rochex A          Fauvarque MO
# 398                Tanji T              Natori S
# 399               Kurucz E                Andó I
#
#                                    primary_affiliation      country
# 0                                                 None         None
# 1    The Breakthrough Toby Robins Breast Cancer Res...           UK
# 2    Laboratory of Immunology, Medical Research Cen...  South Korea
# 3    Department of Molecular Biology and Functional...       Sweden
# 4    Department of Chemistry and Biochemistry, Univ...          USA
# ..                                                 ...          ...
# 395  Section of Microbial Pathogenesis, Yale Univer...          USA
# 396  Department of Biochemistry and Molecular Biolo...          USA
# 397  Commissariat à l'Energie Atomique, DSV, iRTSV,...       France
# 398  Department of Cell Biochemistry, Graduate Scho...        Japan
# 399  Institute of Genetics, Biological Research Cen...      Hungary
#
# [400 rows x 14 columns]

# %% [markdown]
# ### A.2. Process claims from the database
#
# claims is merged with articles

# %%
# Main processing
claims = dfs["assertions"].copy()
print(len(claims))
claims = claims[claims["obsolete"] == False].copy()
print(len(claims))
claims = preprocess_utils.clean_df_from_database(claims)

id_cols = [col for col in claims.columns if "_id" in col]
print(id_cols)

claims = claims.merge(articles, on="article_id", how="left", suffixes=('', '_article'))
id_cols = [col for col in claims.columns if "_id" in col]
print(id_cols)

# Process assertion types
assertion_types = preprocess_utils.clean_df_from_database(dfs["assertion_types"])
assertion_types = assertion_types.rename(columns={"id": "assertion_type_id", "name": "assertion_type"})
claims = claims.merge(assertion_types, on="assertion_type_id", how="left", suffixes=('', '_assertion_type')).drop("assertion_type_id", axis=1)

# Process assessment types
assessment_types = preprocess_utils.clean_df_from_database(dfs["assessment_types"])
assessment_types = assessment_types.rename(columns={"id": "assessment_type_id", "name": "assessment_type"})
claims = claims.merge(assessment_types, on="assessment_type_id", how="left", suffixes=('', '_assessment_type')).drop("assessment_type_id", axis=1)

id_cols = [col for col in claims.columns if "_id" in col]
print(id_cols)
# Out:
# 13941
# 13299
# ['article_id', 'assertion_type_id', 'assessment_type_id']
# ['article_id', 'assertion_type_id', 'assessment_type_id']
# ['article_id']

# %%
claims = claims.drop(['badge_tag_classes','description'], axis=1) # most not consistently used accross dataset
claims = claims.set_index('id', drop=False)
claims = preprocess_utils.add_shangai_ranking(claims)

# %%
claims = claims.apply(preprocess_utils.safe_strip)

# Map assessment types to standardized categories
claims['assessment_type_grouped'] = claims.apply(
    lambda row: plot_info.group_assessment(row['assessment_type']) if row['assertion_type'] == 'major_claim' else None,
    axis=1
)
claims['journal_category'] = claims.apply(
    lambda row: plot_info.categorize_journal(row['impact_factor']) if row['assertion_type'] == 'major_claim' else None,
    axis=1
)

claims["year_binned"] = claims.apply(
    lambda row: plot_info.bin_years(row['year']) if row['assertion_type'] == 'major_claim' else None,
    axis=1
)

conditions = [
    (claims['shangai_ranking_2010'] <= 50) & (~pd.isna(claims['shangai_ranking_2010'])),
    (claims['shangai_ranking_2010'] > 50) & (claims['shangai_ranking_2010'] <= 100),
    (claims['shangai_ranking_2010'] > 100)  & (~pd.isna(claims['shangai_ranking_2010']))
]
choices = ['Top 50', '51-100', '101+']
claims['ranking_category'] = np.select(conditions, choices, default='Not Ranked')

claims.to_csv('preprocessed_data/claims_db.csv', index=False)

string_columns = claims.select_dtypes(include='object').columns.drop(["assessment_type", "journal_name", "primary_affiliation"])
claims_truncated = claims.copy()
for col in string_columns:
    if col in claims_truncated.columns:
        claims_truncated[col] = claims_truncated[col].apply(lambda x: preprocess_utils.truncate_string(x))

# Save truncated dataframe
claims_truncated.to_csv('preprocessed_data/claims_db_truncated_for_llm.csv', index=False)
claims_truncated
# Out:
#           id                  content  article_id  rank  pmid  \
# id
# 5838    5838  <p>Belozerov VE, Lin...      2049.0     1  None
# 693      693                               2517.0     1  None
# 695      695                               2517.0     1  None
# 5840    5840  Verified by many sub...      2204.0     1  None
# 5839    5839  Activation of a cell...      2204.0     1  None
# ...      ...                      ...         ...   ...   ...
# 14468  14468  The DIF antiserum us...      2898.0     1  None
# 11330  11330  Although independent...      1577.0     1  None
# 11329  11329  Spatzle (#gene:FBgn0...      1577.0     1  None
# 11350  11350  Although independent...      1577.0     1  None
# 11349  11349  Spatzle (#gene:FBgn0...      1577.0     3  None
#
#                    authors_txt                    title  pmid_article volume  \
# id
# 5838   Zhuang ZH;Zhou Y;Yu ...  Regulation of Drosop...    16014325.0     18
# 693    Choe KM;Werner T;Stö...  Requirement for a pe...    11872802.0    296
# 695    Choe KM;Werner T;Stö...  Requirement for a pe...    11872802.0    296
# 5840   Zettervall CJ;Anderl...  A directed screen fo...    15381778.0    101
# 5839   Zettervall CJ;Anderl...  A directed screen fo...    15381778.0    101
# ...                        ...                      ...           ...    ...
# 14468  Williams MJ;Rodrigue...  The 18-wheeler mutat...     9321392.0     16
# 11330  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11329  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11350  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11349  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
#
#        issue  ... assertion_type        label is_assessed  \
# id            ...
# 5838       4  ...      reference    Reference       False
# 693     5566  ...     assessment   Assessment       False
# 695     5566  ...     assessment   Assessment       False
# 5840      39  ...     assessment   Assessment       False
# 5839      39  ...     main_claim   Main claim        True
# ...      ...  ...            ...          ...         ...
# 14468     20  ...        comment      Comment       False
# 11330  Pt 24  ...     assessment   Assessment       False
# 11329  Pt 24  ...     main_claim   Main claim        True
# 11350  Pt 24  ...     assessment   Assessment       False
# 11349  Pt 24  ...    major_claim  Major claim        True
#
#                           assessment_type rank_assessment_type  \
# id
# 5838                                  NaN                  NaN
# 693                          Not assessed                 13.0
# 695                          Not assessed                 13.0
# 5840                             Verified                  1.0
# 5839                             Verified                  1.0
# ...                                   ...                  ...
# 14468                        Not assessed                 13.0
# 11330  Unchallenged, logically consistent                  6.0
# 11329  Unchallenged, logically consistent                  6.0
# 11350  Unchallenged, logically consistent                  6.0
# 11349  Unchallenged, logically consistent                  6.0
#
#       shangai_ranking_2010 assessment_type_grouped journal_category  \
# id
# 5838                   201                    None             None
# 693                   <NA>                    None             None
# 695                   <NA>                    None             None
# 5840                   201                    None             None
# 5839                   201                    None             None
# ...                    ...                     ...              ...
# 14468                  201                    None             None
# 11330                   10                    None             None
# 11329                   10                    None             None
# 11350                   10                    None             None
# 11349                   10            Unchallenged       Low Impact
#
#       year_binned ranking_category
# id
# 5838         None             101+
# 693          None       Not Ranked
# 695          None       Not Ranked
# 5840         None             101+
# 5839         None             101+
# ...           ...              ...
# 14468        None             101+
# 11330        None           Top 50
# 11329        None           Top 50
# 11350        None           Top 50
# 11349   2007-2011           Top 50
#
# [13299 rows x 28 columns]

# %%
claims_truncated
# Out:
#           id                  content  article_id  rank  pmid  \
# id
# 5838    5838  <p>Belozerov VE, Lin...      2049.0     1  None
# 693      693                               2517.0     1  None
# 695      695                               2517.0     1  None
# 5840    5840  Verified by many sub...      2204.0     1  None
# 5839    5839  Activation of a cell...      2204.0     1  None
# ...      ...                      ...         ...   ...   ...
# 14468  14468  The DIF antiserum us...      2898.0     1  None
# 11330  11330  Although independent...      1577.0     1  None
# 11329  11329  Spatzle (#gene:FBgn0...      1577.0     1  None
# 11350  11350  Although independent...      1577.0     1  None
# 11349  11349  Spatzle (#gene:FBgn0...      1577.0     3  None
#
#                    authors_txt                    title  pmid_article volume  \
# id
# 5838   Zhuang ZH;Zhou Y;Yu ...  Regulation of Drosop...    16014325.0     18
# 693    Choe KM;Werner T;Stö...  Requirement for a pe...    11872802.0    296
# 695    Choe KM;Werner T;Stö...  Requirement for a pe...    11872802.0    296
# 5840   Zettervall CJ;Anderl...  A directed screen fo...    15381778.0    101
# 5839   Zettervall CJ;Anderl...  A directed screen fo...    15381778.0    101
# ...                        ...                      ...           ...    ...
# 14468  Williams MJ;Rodrigue...  The 18-wheeler mutat...     9321392.0     16
# 11330  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11329  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11350  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
# 11349  Shia AK;Glittenberg ...  Toll-dependent antim...    19934223.0    122
#
#        issue  ... assertion_type        label is_assessed  \
# id            ...
# 5838       4  ...      reference    Reference       False
# 693     5566  ...     assessment   Assessment       False
# 695     5566  ...     assessment   Assessment       False
# 5840      39  ...     assessment   Assessment       False
# 5839      39  ...     main_claim   Main claim        True
# ...      ...  ...            ...          ...         ...
# 14468     20  ...        comment      Comment       False
# 11330  Pt 24  ...     assessment   Assessment       False
# 11329  Pt 24  ...     main_claim   Main claim        True
# 11350  Pt 24  ...     assessment   Assessment       False
# 11349  Pt 24  ...    major_claim  Major claim        True
#
#                           assessment_type rank_assessment_type  \
# id
# 5838                                  NaN                  NaN
# 693                          Not assessed                 13.0
# 695                          Not assessed                 13.0
# 5840                             Verified                  1.0
# 5839                             Verified                  1.0
# ...                                   ...                  ...
# 14468                        Not assessed                 13.0
# 11330  Unchallenged, logically consistent                  6.0
# 11329  Unchallenged, logically consistent                  6.0
# 11350  Unchallenged, logically consistent                  6.0
# 11349  Unchallenged, logically consistent                  6.0
#
#       shangai_ranking_2010 assessment_type_grouped journal_category  \
# id
# 5838                   201                    None             None
# 693                   <NA>                    None             None
# 695                   <NA>                    None             None
# 5840                   201                    None             None
# 5839                   201                    None             None
# ...                    ...                     ...              ...
# 14468                  201                    None             None
# 11330                   10                    None             None
# 11329                   10                    None             None
# 11350                   10                    None             None
# 11349                   10            Unchallenged       Low Impact
#
#       year_binned ranking_category
# id
# 5838         None             101+
# 693          None       Not Ranked
# 695          None       Not Ranked
# 5840         None             101+
# 5839         None             101+
# ...           ...              ...
# 14468        None             101+
# 11330        None           Top 50
# 11329        None           Top 50
# 11350        None           Top 50
# 11349   2007-2011           Top 50
#
# [13299 rows x 28 columns]

# %% [markdown]
# ### A.3. Process authors from database
#
# there are about two author per article... though the total of authors is 797 so some are missing.

# %%
a = preprocess_utils.clean_df_from_database(dfs["authors"])  
a[a["article_id"] == 2053]
# Out:
#    id  article_id        name  sex  career_stage_id  leading_author  \
# 0   2        2053      Brun S    1                3           False
# 1   3        2053  Lemaitre B    1                4            True
#
#    first_author  expertise_level_id
# 0          True                   2
# 1         False                   2

# %%
len(a)
# Out:
# 797

# %%
a[a["name"] == "Lemaitre B"].head()
# Out:
#     id  article_id        name  sex  career_stage_id  leading_author  \
# 1    3        2053  Lemaitre B    1                4            True
# 7    8        3437  Lemaitre B    1                4            True
# 14  16        2801  Lemaitre B    1                4            True
# 30  36        2617  Lemaitre B    1                4            True
# 44  56        2869  Lemaitre B    1                4            True
#
#     first_author  expertise_level_id
# 1          False                   2
# 7          False                   2
# 14         False                   2
# 30         False                   2
# 44         False                   2

# %%
a[a["article_id"] == 2451]
# Out:
#       id  article_id           name  sex  career_stage_id  leading_author  \
# 17    19        2451  De Gregorio E    1                3           False
# 95    20        2451     Lemaitre B    1                5           False
# 789  795        2451        Brey PT    1                5            True
#
#      first_author  expertise_level_id
# 17           True                   2
# 95          False                   2
# 789         False                   2

# %%
authors = preprocess_utils.clean_df_from_database(dfs["authors"].copy())
authors
career_stage = dfs["career_stages"].rename(columns={"id": "career_stage_id"})
authors = authors.merge(career_stage, on="career_stage_id", how="left", suffixes=('', '_career_stage')).drop("career_stage_id", axis=1)
expertise_level = dfs["expertise_levels"].rename(columns={"id": "expertise_level_id"})
authors = authors.merge(expertise_level, on="expertise_level_id", how="left", suffixes=('', '_expertise_level')).drop("expertise_level_id", axis=1)
authors = authors.rename(columns={"name_career_stage": "career_stage", "name_expertise_level": "expertise_level", "id": "author_id"})

# Convert sex values: 1 to "Male", 0 to "Female"
authors.loc[authors["sex"] == 1, "sex"] = "Male"
authors.loc[authors["sex"] == 0, "sex"] = "Female"

authors
# Out:
# /var/folders/pj/15hxgl0j1wg2w_t5k7bvnq5c0000gn/T/ipykernel_50444/4002741855.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   authors.loc[authors["sex"] == 1, "sex"] = "Male"
#      author_id  article_id               name     sex  leading_author  \
# 0            2        2053             Brun S    Male           False
# 1            3        2053         Lemaitre B    Male            True
# 2            1        1650         Charroux B    Male           False
# 3           97        2149        Söderhäll K    Male            True
# 4            5        2278        Silverman N    Male           False
# ..         ...         ...                ...     ...             ...
# 792        797        2067         Cerenius L    Male            True
# 793        798        2122         Higgins DE    Male            True
# 794        799        2184  Mengin-Lecreulx D    Male            True
# 795        800        2130           Moore KJ  Female            True
# 796        700        1990           Matova N  Female           False
#
#      first_author career_stage expertise_level
# 0            True     Post-doc     Experienced
# 1           False    Junior PI     Experienced
# 2            True     Post-doc     Experienced
# 3           False    Senior PI     Experienced
# 4            True     Post-doc        Newcomer
# ..            ...          ...             ...
# 792         False    Senior PI     Experienced
# 793         False    Senior PI        Newcomer
# 794         False    Senior PI     Experienced
# 795         False    Junior PI        Newcomer
# 796          True     Post-doc        Newcomer
#
# [797 rows x 8 columns]

# %%
# check authors thare not both leading and first authors, or that are neither using XOR
authors[~(authors["leading_author"] ^ authors["first_author"])]
# Out:
#      author_id  article_id           name     sex  leading_author  \
# 95          20        2451     Lemaitre B    Male           False
# 194        127        2113   Schneider DS    Male           False
# 195        197        3440     Lemaitre B    Male           False
# 196        169        2184     Lemaitre B    Male           False
# 243        250        1947   Schneider DS    Male            True
# 256        260        1763   Schneider DS    Male           False
# 257        252        2730  Shahabuddin M    Male           False
# 287        303        3458     Hultmark D    Male            True
# 329        251        2730   Schneider DS    Male            True
# 334        378        1702    Williams MJ    Male            True
# 342        365        3447       Rizki TM    Male            True
# 350        363        3448       Rizki TM    Male            True
# 355        364        3292       Rizki TM    Male            True
# 356        370        3450       Gateff E  Female            True
# 368        362        3273       Rizki TM    Male            True
# 371        371        3449       Gateff E  Female            True
# 473        483        2764       Imler JL    Male            True
# 565        497        2122     Perrimon N    Male           False
# 658        647        3446       Nappi AJ    Male            True
# 686        702        1762      Wegner KM    Male            True
# 741        720        2067    Söderhäll K    Male           False
# 742        706        2130   Ezekowitz RA    Male           False
# 790        792        3273    Bellotti RA    Male           False
#
#      first_author career_stage expertise_level
# 95          False    Senior PI     Experienced
# 194         False    Junior PI     Experienced
# 195         False    Junior PI     Experienced
# 196         False    Junior PI     Experienced
# 243          True    Senior PI     Experienced
# 256         False    Senior PI     Experienced
# 257         False    Junior PI        Newcomer
# 287          True    Senior PI     Experienced
# 329          True    Junior PI        Newcomer
# 334          True    Junior PI     Experienced
# 342          True    Senior PI     Experienced
# 350          True    Senior PI     Experienced
# 355          True    Senior PI     Experienced
# 356          True    Senior PI     Experienced
# 368          True     Post-doc     Experienced
# 371          True    Senior PI     Experienced
# 473          True    Junior PI        Newcomer
# 565         False    Senior PI     Experienced
# 658          True    Junior PI     Experienced
# 686          True     Post-doc        Newcomer
# 741         False    Senior PI     Experienced
# 742         False    Senior PI        Newcomer
# 790         False       Master        Newcomer

# %%
#authors = authors.merge(articles, on="article_id", how="left", suffixes=('', '_article'))
#authors.sort_values(by=["article_id", "author_id", ])
authors= preprocess_utils.build_author_key(authors, author_name_col="name", key_col="author_key")

# %%
for idr, row in authors[authors["author_key"] == "wang z"].iterrows():
    print(row["article_id"], end=" ")
    this_article = articles[articles["article_id"] == row["article_id"]]
    print(this_article["title"].values[0], this_article["journal_name"].values[0], this_article["year"].values[0])
# Out:
# 1557 Pathogen entrapment by transglutaminase--a conserved early innate immune mechanism. PLoS pathogens 2010
# 1423 Host and pathogen glycosaminoglycan-binding proteins modulate antimicrobial peptide responses in Drosophila melanogaster. Infection and immunity 2011

# %%
for idr, row in authors[authors["author_key"] == "zhang z"].iterrows():
    print(row["article_id"], end=" ")
    this_article = articles[articles["article_id"] == row["article_id"]]
    print(this_article["title"].values[0], this_article["journal_name"].values[0], this_article["year"].values[0])
# Out:
# 1491 Functional role of charged residues in drosomycin, a Drosophila antifungal peptide. Developmental and comparative immunology 2010
# 1606 Identification of a cis-regulatory element required for 20-hydroxyecdysone enhancement of antimicrobial peptide gene expression in Drosophila melanogaster. Insect molecular biology 2009

# %% [markdown]
# After a google search:
# * 1557 Pathogen entrapment by transglutaminase--a conserved early innate immune mechanism. PLoS pathogens 2010 **is Zhi Wang**
# * 1423 Host and pathogen glycosaminoglycan-binding proteins modulate antimicrobial peptide responses in Drosophila melanogaster. Infection and immunity 2011 **is Zhipeng Wang**
# * 1491 Functional role of charged residues in drosomycin, a Drosophila antifungal peptide. Developmental and comparative immunology 2010 **is Zhenting Zhang**
# * 1606 Identification of a cis-regulatory element required for 20-hydroxyecdysone enhancement of antimicrobial peptide gene expression in Drosophila melanogaster. Insect molecular biology 2009 **is assumed to be Zhaolin Zhang**

# %%
authors.loc[(authors["author_key"] == "wang z") & (authors["article_id"] == 1557),"name"] = "Wang Zhi"
authors.loc[(authors["author_key"] == "wang z") & (authors["article_id"] == 1423),"name"] = "Wang Zhipeng"
authors.loc[(authors["author_key"] == "zhang z") & (authors["article_id"] == 1491),"name"] = "Zhang Zhenting"
authors.loc[(authors["author_key"] == "zhang z") & (authors["article_id"] == 1606),"name"] = "Zhang Zhaolin"

# %%
authors= preprocess_utils.build_author_key(authors, author_name_col="name", key_col="author_key")
authors = authors.apply(preprocess_utils.safe_strip)
# replace all Promislow D with Promislow DE and promislow d with promilsow de,
authors.loc[authors["author_key"] == "promislow d", "name"] = "Promislow DE"
authors.loc[authors["author_key"] == "promislow d", "author_key"] = "promislow de"

# correct hoffmann ja as PI instead of Engineer / Technician
authors.loc[(authors["author_key"] == "hoffmann ja") & (authors["career_stage"] == "Engineer / Technician"), "career_stage"] = "Senior PI"

authors = authors.drop(columns=["sex"]) # This is in the excel files
authors.to_csv('preprocessed_data/authors_db.csv', index=False)

# %%
authors[authors["author_key"] == "hoffmann ja"]
# Out:
#      author_id  article_id         name  leading_author  first_author  \
# 10          12        3096  Hoffmann JA            True         False
# 19          22        3015  Hoffmann JA            True         False
# 35          44        2593  Hoffmann JA            True         False
# 46          58        3052  Hoffmann JA            True         False
# 133        141        3141  Hoffmann JA            True         False
# 135        143        2891  Hoffmann JA            True         False
# 170        179        3011  Hoffmann JA            True         False
# 185        195        2945  Hoffmann JA            True         False
# 188        199        2978  Hoffmann JA            True         False
# 209        203        2849  Hoffmann JA            True         False
# 237        211        3047  Hoffmann JA            True         False
# 344        353        2976  Hoffmann JA            True         False
# 345        357        3014  Hoffmann JA            True         False
# 351        355        3034  Hoffmann JA            True         False
# 463        476        2963  Hoffmann JA            True         False
# 470        480        3004  Hoffmann JA            True         False
#
#     career_stage expertise_level   author_key
# 10     Senior PI     Experienced  hoffmann ja
# 19     Senior PI     Experienced  hoffmann ja
# 35     Senior PI     Experienced  hoffmann ja
# 46     Senior PI     Experienced  hoffmann ja
# 133    Senior PI     Experienced  hoffmann ja
# 135    Senior PI     Experienced  hoffmann ja
# 170    Senior PI     Experienced  hoffmann ja
# 185    Senior PI     Experienced  hoffmann ja
# 188    Senior PI     Experienced  hoffmann ja
# 209    Senior PI     Experienced  hoffmann ja
# 237    Senior PI     Experienced  hoffmann ja
# 344    Senior PI     Experienced  hoffmann ja
# 345    Senior PI     Experienced  hoffmann ja
# 351    Senior PI     Experienced  hoffmann ja
# 463    Senior PI     Experienced  hoffmann ja
# 470    Senior PI     Experienced  hoffmann ja
